# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/lirazsgroup/Death/main/20220327%20annual-number-of-deaths-by-cause.csv'
death_df = pd.read_csv(url)

# %% [markdown]
# ![medical-doctor-cod-angel-medical_malpractice-malpractice_lawsuits-lcan891_low.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **תיאור הנתונים**

# %%
death_df.shape
# Out:
# (8254, 36)

# %%
death_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Number of executions (Amnesty International)',
#        'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Malaria - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drowning - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)',
#        'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)',
# ...

# %%
death_df.head(10)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
# 5  Afghanistan  AFG  2013                                            2
# 6  Afghanistan  AFG  2014                                            6
# 7  Afghanistan  AFG  2015                                            1
# 8  Afghanistan  AFG  2016                                            6
# 9  Afghanistan  AFG  1990                                          NaN
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# ...

# %% [markdown]
# **סידור וטיוב הנתונים**

# %% [markdown]
# שינוי שמות העמודות לשם נוחות העבודה עם הנתונים

# %%
death_df.rename(columns = {'Entity' : 'Entity', 'Code' : 'Code' , 'Year' : 'Year', 'Number of executions (Amnesty International)' : 'executions', 'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)' : 'Meningitis' 
                           , 'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)' : 'Neoplasms', 'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)' : 'Fire', 
                           'Deaths - Malaria - Sex: Both - Age: All Ages (Number)' : 'Malaria', 'Deaths - Drowning - Sex: Both - Age: All Ages (Number)': 'Drowning', 
                           'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)' : 'Interpersonal violence', 'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)' : 'HIV/AIDS',
                           'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)' : 'Drug use disorders', 'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)' : 'Tuberculosis',
                           'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)' : 'Road injuries', 'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)' : 'Maternal disorders',
                           'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)' : 'Lower respiratory infections', 'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)' : 'Neonatal disorders',
                           'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)' : 'Alcohol use disorders', 'Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)': 'Exposure to forces of nature',
                           'Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)' : 'Diarrheal diseases', 'Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)' : 'Environmental heat and cold exposure',
                           'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)' : 'Nutritional deficiencies', 'Deaths - Self-harm - Sex: Both - Age: All Ages (Number)' : 'Self-harm', 
                           'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)' : 'Conflict and terrorism', 'Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)' : 'Diabetes mellitus',
                           'Deaths - Poisonings - Sex: Both - Age: All Ages (Number)' : 'Poisonings', 'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)' : 'Protein-energy malnutrition',
                           'Terrorism (deaths)' : 'Terrorism' , 'Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)' : 'Cardiovascular diseases', 'Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)':
                           'Chronic kidney disease', 'Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)': 'Chronic respiratory diseases', 'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)': 
                           'Cirrhosis and other chronic liver diseases', 'Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)' : 'Digestive diseases', 'Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)':
                           'Acute hepatitis', 'Deaths - Alzheimers disease and other dementias - Sex: Both - Age: All Ages (Number)' : 'Alzheimers disease and other dementias' , 'Deaths - Parkinsons disease - Sex: Both - Age: All Ages (Number)':
                           'Parkinsons disease'}, inplace = True)

# %% [markdown]
# לשים ♥ שעמודות אלציימהר ופרקינסון לא משתנות בגלל הגרש

# %% [markdown]
# נבדוק האם קיימים ערכים חסרים בדאטה

# %%
death_df.isnull().sum()
# Out:
# Entity                                                                                      0
# Code                                                                                     2048
# Year                                                                                        0
# executions                                                                               7987
# Meningitis                                                                                244
# Neoplasms                                                                                 244
# Fire                                                                                      244
# Malaria                                                                                   244
# Drowning                                                                                  244
# Interpersonal violence                                                                    244
# ...

# %% [markdown]
# ניתן לראות שתחת הוצאה להורג רוב הערכים חסרים ומספר ההרוגים בקטגוריה זו זניח ולכן נשמיט את העמודה, כמו כן עמודת קוד אינה תורמת לניתוח ולכן נשמיטה גם

# %%
death_df=death_df.drop(['Code', 'executions'],axis=1)

# %% [markdown]
# נאחד בין שתי העמודות של טרור לעמודה אחת

# %%
sum_column = death_df["Conflict and terrorism"] + death_df["Terrorism"]
death_df["Terror"] = sum_column
death_df=death_df.drop(['Conflict and terrorism', 'Terrorism'],axis=1)

# %% [markdown]
# כדי שנוכל לבצע ניתוח נכון שלא יכלול בתוכו כפילויות, נסיר מיקומים של יבשות ונשאיר מיקומים שמייצגים מדינות בלבד

# %%
death_df.drop(death_df[death_df['Entity'] == 'World'].index , inplace=True)
death_df.drop(death_df[death_df.Entity == 'Western Europe'].index , inplace=True)
death_df.drop(death_df[death_df.Entity == 'East Asia'].index , inplace=True)
death_df.drop(death_df[death_df.Entity == 'Southeast Asia'].index , inplace=True)

# %% [markdown]
# נשלים ערכים ריקים באמצעות אפסים מאחר ואין קשר כלשהו בין המדינות בין סיבות המוות ובין השנים

# %%
death_df.fillna(0,inplace=True)

# %%
death_df
# Out:
#            Entity  Year  Meningitis  Neoplasms   Fire  Malaria  Drowning  \
# 0     Afghanistan  2007      2933.0    15925.0  481.0    393.0    2127.0
# 1     Afghanistan  2008      2731.0    16148.0  462.0    255.0    1973.0
# 2     Afghanistan  2009      2460.0    16383.0  448.0    239.0    1852.0
# 3     Afghanistan  2011      2327.0    17094.0  448.0    390.0    1775.0
# 4     Afghanistan  2012      2254.0    17522.0  445.0     94.0    1716.0
# ...           ...   ...         ...        ...    ...      ...       ...
# 8249     Zimbabwe  2015      1439.0    11161.0  632.0   2518.0     770.0
# 8250     Zimbabwe  2016      1457.0    11465.0  648.0   2050.0     801.0
# 8251     Zimbabwe  2017      1460.0    11744.0  654.0   2116.0     818.0
# 8252     Zimbabwe  2018      1450.0    12038.0  657.0   2088.0     825.0
# 8253     Zimbabwe  2019      1450.0    12353.0  662.0   2068.0     827.0
#
#       Interpersonal violence  HIV/AIDS  Drug use disorders  ...  \
# ...

# %% [markdown]
# עד כאן החלק של הפתיחה

# %% [markdown]
# **חקר הנתונים**

# %% [markdown]
# נסכום את סך כל המתים בכל קטגוריה ובאמצעות גרף נראה מה הסיבה שבגללה מתים הכי הרבה אנשים בעולם

# %%
death_df["sum"] = death_df.sum(axis=1)

# %% [markdown]
#  לשים ♥ שיש כאן יש בעיה כי אנחנו סוכמות גם את העמודה של השנה

# %%
df_new =death_df.sum(axis=0).reset_index()
df_new=df_new.rename(columns={'index': 'cause', 0:'total deaths in billions'})
df_new.drop(df_new.index[[0,1 , -1]],inplace=True)
df_new.convert_dtypes()
df_new = df_new.sort_values(by=["total deaths in billions"],ascending=False)

# %%
sns.barplot(x='cause', y='total deaths in billions', data=df_new)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# לראות אם אפשר לייבא plotly.express   ♥  ובעזרתו לעשות גרפים יותר טובים

# %% [markdown]
# **ניתן לראות שרוב מקרי המוות בעולם נגרמו כתוצאה ממחלות לב וכלי דם*

# %% [markdown]
# ![the+leading+causes+of+death+in+the+world.jpg](attachment:f3336752-4f33-43ed-9edd-9e2f36b81be0.jpg)

# %%
israel =death_df[death_df["Entity"] == "Israel"]
df_cols = death_df.columns
df_cols=df_cols.drop(['sum'])

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________

# %%
israelcopy["sum"] = israel.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-bb710465c436> in <module>
# ----> 1 israelcopy["sum"] = israel.sum(axis=1)
#
# NameError: name 'israel' is not defined

# %%
israelcopy
# Out:
#       Entity  Year  Meningitis  Neoplasms  Fire  Malaria  Drowning  \
# 3669  Israel  1990        43.0     7083.0  38.0      0.0      66.0
# 3670  Israel  1991        40.0     7583.0  38.0      0.0      66.0
# 3671  Israel  1992        42.0     8083.0  39.0      0.0      65.0
# 3672  Israel  1993        48.0     8383.0  39.0      0.0      61.0
# 3673  Israel  1994        41.0     8781.0  40.0      0.0      59.0
# 3674  Israel  1995        38.0     9230.0  41.0      0.0      56.0
# 3675  Israel  1996        37.0     9528.0  41.0      0.0      51.0
# 3676  Israel  1997        44.0     9795.0  44.0      0.0      48.0
# 3677  Israel  1998        42.0    10099.0  43.0      0.0      44.0
# 3678  Israel  1999        42.0    10275.0  44.0      0.0      46.0
# 3679  Israel  2000        39.0    10437.0  46.0      0.0      48.0
# 3680  Israel  2001        38.0    10531.0  45.0      0.0      52.0
# 3681  Israel  2002        38.0    10730.0  45.0      0.0      52.0
# ...

# %%
sns.barplot(data =israelcopy, x='Year', y='sum',linewidth=3)
plt.xticks(rotation=100)
plt.show()

# %%
#data=death_df[['Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)','Deaths - Drowning - Sex: Both - Age: All Ages (Number)',']]
#sns.heatmap(israel.corr(), vmin=0 , vmax = 1 ,cmap='jet',linewidths=0.5 , annot=True)

# %% [markdown]
# ניתן לראות שהעמודות בגרף הולכות וגדלות,בעקבות גידול האוכולוסיה מידי שנה. לכן נתייחס לעמודות בגרף אשר חריגות ביחס לעמודות הסמוכות להן.

# %% [markdown]
# לאחר התבוננות בגרף בשנים 2002 ו2014 קיימת חריגה , אשר נירצה לבדוק את סיבותיה, לשם כך נמיין בשנים אלו את סיבותם המוות

# %%
israel=death_df.loc[death_df.Entity=='Israel']

# %%
alp=israel.loc[israel.Year==2002]
alp

# %%
alp.max(axis=1).to_frame()

# %%
sns.scatterplot(data=israel, x='Year', y='Terrorism (deaths)')
#nn=israel.loc[israel.Year=='2002']
#israel=death_df.loc[death_df.Entity=='Israel'].copy()

# %% [markdown]
# יאיר:לכיוון זכויות אדם באום מסקנות
# קודם כל לצמצם עמודות ולעשות קורלציה

# %% [markdown]
# מצמצות את הטבלה למקרי מוות רלוונטים

# %%
#d=death_df.dropna(subset = ['Code','Deaths - Meningitis - Sex: Both - Age: All Ages (Number)','Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)','Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)','Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)','Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)','Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)','Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)','Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)','Deaths - Poisonings - Sex: Both - Age: All Ages (Number)','Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)','Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)','Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)','Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)','Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)','Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)'])

# %%
d=death_df[['Entity','Year','Number of executions (Amnesty International)','Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)','Deaths - Malaria - Sex: Both - Age: All Ages (Number)','Deaths - Drowning - Sex: Both - Age: All Ages (Number)','Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)','Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)','Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)','Deaths - Road injuries - Sex: Both - Age: All Ages (Number)','Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)','Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)','Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)','Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)','Deaths - Self-harm - Sex: Both - Age: All Ages (Number)','Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)','Terrorism (deaths)','Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)'
]]

# %%
d

# %%
d =d.rename(columns={'Entity','Year','Number of executions (Amnesty International)','Deaths - Fire, heat, and hot substances','Deaths - Malaria ','Deaths - Drowning','Deaths - Interpersonal violence','Deaths - HIV/AIDS','Deaths - Drug use disorders','Deaths - Road injuries','Deaths - Alcohol use disorders','Deaths - Exposure to forces of nature','Deaths - Environmental heat and cold exposure','Deaths - Nutritional deficiencies','Deaths - Self-harm','Deaths - Conflict and terrorism','Terrorism (deaths)','Deaths - Acute hepatitis'
})

# %%
d
